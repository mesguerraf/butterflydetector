# %%
import sys
import butterflydetector

# %%
from butterflydetector.data_manager.coco import Coco
BBOX_POINTS = [
    'top_left',
    'top_right',
    'bottom_right',
    'bottom_left',
    'center',
]

# %%
ds = Coco(Coco.train_image_dir, Coco.train_annotations)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
from PIL import Image
Image.open('../datasets/coolingTowersV3/images/train/000002.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F9E3C7B9D10>

# %%
ds[2]
# Out:
# (tensor([[[-0.4054, -0.2513, -0.1486,  ..., -2.1008, -2.1008, -2.1008],
#           [-0.2684, -0.1657, -0.0972,  ..., -2.1008, -2.1008, -2.1008],
#           [-0.0629, -0.0287, -0.0287,  ..., -2.1008, -2.1008, -2.1008],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -1.9809, -1.9638, -1.9638],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.9638, -1.9809, -1.9809],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.9638, -1.9980, -2.0152]],
#
#          [[-0.6702, -0.5126, -0.3725,  ..., -2.0182, -2.0182, -2.0182],
#           [-0.4076, -0.3025, -0.2500,  ..., -2.0182, -2.0182, -2.0182],
#           [-0.0399, -0.0049, -0.0049,  ..., -2.0182, -2.0182, -2.0182],
#           ...,
#           [-2.0007, -2.0182, -2.0182,  ..., -1.9657, -1.9482, -1.9482],
#           [-2.0007, -2.0007, -2.0007,  ..., -1.9482, -1.9657, -1.9657],
#           [-1.9832, -1.9832, -1.9657,  ..., -1.9482, -1.9832, -2.0007]],
#
# ...
